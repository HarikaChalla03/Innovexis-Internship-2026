# %% [markdown]
# # **MYSQL Connection**

# %%
import mysql.connector
import os
from dotenv import load_dotenv
load_dotenv()

conn_mysql = mysql.connector.connect(
    host=os.getenv("DB_HOST"),
    user=os.getenv("DB_USER"),
    password=os.getenv("DB_PASSWORD"),
    database= os.getenv("DB_NAME") 
)
cursor_mysql = conn_mysql.cursor()
print("MySQL connection established!")
# Out:
# MySQL connection established!

# %% [markdown]
# # **Creating a Database in MySQL**

# %%
cursor_mysql.execute(
    f"CREATE DATABASE IF NOT EXISTS {os.getenv('DB_NAME')};"
)
print(f"MySQL database '{os.getenv('DB_NAME')}' created successfully!")
# Out:
# MySQL database 'Local_Food_Wastage_Management_System' created successfully!

# %%
cursor_mysql.execute(
    f"USE {os.getenv('DB_NAME')};"
)

# %%
cursor_mysql.execute("SHOW TABLES;")
for table in cursor_mysql:
   print(table)
# Out:
# ('claims',)
# ('final_merged_data',)
# ('food_listings',)
# ('providers',)
# ('receivers',)

# %% [markdown]
# # **Connecting to Python with MySQL**

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
import cryptography
import os
from dotenv import load_dotenv
load_dotenv() #Load environment variables

# Create connection
engine = create_engine(
    f"mysql+pymysql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}"
    f"@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
)

# Read data
df = pd.read_csv("C:/Users/Harika challa/Innovexis/Project-2/final_merged_data.csv")

# Load to MySQL
df.to_sql("final_merged_data", engine, if_exists="append", index=False)

print("Data inserted using to_sql()")
# Out:
# Data inserted using to_sql()
